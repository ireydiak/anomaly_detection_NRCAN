# %% [markdown]
# # Robustness evaluation of unsupervised deep learning model

# %%
import torch
import numpy as np
from sklearn.manifold import TSNE
import pandas as pd
import matplotlib.pyplot as plt
from datamanager.dataset import KDD10Dataset, NSLKDDDataset, IDS2018Dataset
import matplotlib.ticker as ticker
import torch
from torch.utils.data import Dataset, Subset, DataLoader
from model.reconstruction import AutoEncoder as AE
from trainer.reconstruction import AutoEncoderTrainer
import os
from utils.metrics import compute_metrics, _estimate_optimal_threshold

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### KDD 10

# %%
dataset_path = "../data/processed/kdd/3_minified/KDD10percent_minified.npz"
dataset = KDD10Dataset(path=dataset_path, pct=1.0)
train_set, test_set, val_set = dataset.split_train_test(test_pct= .5,
                         label= 0,
                         holdout=0.4,
                         contamination_rate=0.25,
                         validation_ratio= 0.0,
                         debug=True)
# Out:
# Dataset size
# Positive class :97278
# Negative class :396743
#
# Training set
# Contamination rate: 0.04674675636713119
#
# 494021 464837

# %%
len(np.unique(train_set[:][0]))/len(train_set[:][0])
# Out:
# 0.028212397885631908

# %%
y =  train_set[:][1]
normal_idx = np.where(y == 0)
abnormal_idx = np.where(y == 1)

# %%
train_set[:][0]
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 7.49954238e-07, 0.00000000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 7.49954238e-07, 0.00000000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.48837072e-06, 0.00000000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.48837072e-06, 0.00000000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00]])

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(train_set[:][0])

# %%
# fig = plt.figure(figsize=(10, 5))
# ax = fig.add_subplot(projection='3d')
# ax.scatter3D(X[:,0], X[:,1], X[:,2])
# plt.show()

# %%
# X_embedded

# %%
fig = plt.figure(figsize=(10, 8))
plt.scatter(X_embedded[normal_idx,0], X_embedded[normal_idx,1], c='blue', label='normal')
plt.scatter(X_embedded[abnormal_idx,0], X_embedded[abnormal_idx,1], c='red', label='attack')
plt.title("")
plt.xlabel('x', fontsize=18)
plt.ylabel('y', fontsize=18)
plt.tick_params(labelsize=18)
plt.legend(fontsize=18)
fig.savefig('kddtsne_25.pdf')
plt.show()

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(train_set[:][0])

# %% [markdown]
# ### NSL-KDD

# %%
dataset_path = "../data/processed/nslkdd/3_minified/NSL-KDD_minified.npz"
dataset = NSLKDDDataset(path=dataset_path, pct=1.0)
train_set, test_set, val_set = dataset.split_train_test(test_pct= .5,
                         label= 0,
                         holdout=0.2,
                         contamination_rate=0.25,
                         validation_ratio= 0.0,
                         debug=True)
# Out:
# Dataset size
# Positive class :71463
# Negative class :77054
#
# Training set
# Contamination rate: 0.08486935866983374
#
# 148517 137797

# %%
y =  train_set[:][1]
normal_idx = np.where(y == 0)
abnormal_idx = np.where(y == 1)

# %%
len(np.unique(train_set[:][0]))/len(train_set[:][0])
# Out:
# 0.2877672209026128

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(train_set[:][0])

# %%
fig = plt.figure(figsize=(10, 8))
plt.scatter(X_embedded[normal_idx,0], X_embedded[normal_idx,1], c='blue', label='normal')
plt.scatter(X_embedded[abnormal_idx,0], X_embedded[abnormal_idx,1], c='red', label='attack')
plt.title("")
plt.xlabel('x', fontsize=18)
plt.ylabel('y', fontsize=18)
plt.tick_params(labelsize=18)
plt.legend(fontsize=18)
fig.savefig('nsltsne_25.pdf')
plt.show()

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', init='random', perplexity=50).fit_transform(train_set[:][0])
fig = plt.figure(figsize=(10, 8))
plt.scatter(X_embedded[normal_idx,0], X_embedded[normal_idx,1], c='blue', label='normal')
plt.scatter(X_embedded[abnormal_idx,0], X_embedded[abnormal_idx,1], c='red', label='attack')
plt.title("")
plt.xlabel('x', fontsize=18)
plt.ylabel('y', fontsize=18)
plt.tick_params(labelsize=18)
plt.legend(fontsize=18)
fig.savefig('nsltsne_25_.pdf')
plt.show()

# %% [markdown]
# ### CIC IDS 2018

# %%
dataset_path = "../data/processed/feature_group_5.npz"
dataset = IDS2018Dataset(path=dataset_path, pct=.05)
train_set, test_set, val_set = dataset.split_train_test(test_pct= .5,
                         label= 0,
                         holdout=0.4,
                         contamination_rate=0.25,
                         validation_ratio= 0.0,
                         debug=True)
# Out:
# Dataset size
# Positive class :137346
# Negative class :669511
#
# Training set
# Contamination rate: 0.03941002611265747
#
# 806857 765652

# %%
y =  train_set[:][1]
normal_idx = np.where(y == 0)
abnormal_idx = np.where(y == 1)

# %%
len(np.unique(train_set[:][0]))/len(train_set[:][0])
# Out:
# 9.012918591638211

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(train_set[:][0])

# %%
fig = plt.figure(figsize=(10, 8))
plt.scatter(X_embedded[normal_idx,0], X_embedded[normal_idx,1], c='blue', label='normal')
plt.scatter(X_embedded[abnormal_idx,0], X_embedded[abnormal_idx,1], c='red', label='attack')
plt.title("")
plt.xlabel('x', fontsize=18)
plt.ylabel('y', fontsize=18)
plt.tick_params(labelsize=18)
plt.legend(fontsize=18)
fig.savefig('cicids_25.pdf')
plt.show()
# Out:
# C:\Users\nkad2101\AppData\Local\Temp\ipykernel_7256\1430074103.py:9: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.savefig('cicids_25.pdf')
# C:\Users\nkad2101\Miniconda3\envs\mlenv\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig = plt.figure(figsize=(10, 8))
plt.scatter(X_embedded[normal_idx,0], X_embedded[normal_idx,1], c='blue', label='normal')
plt.scatter(X_embedded[abnormal_idx,0], X_embedded[abnormal_idx,1], c='red', label='Infiltration')
plt.title("")
plt.xlabel('x', fontsize=18)
plt.ylabel('y', fontsize=18)
plt.tick_params(labelsize=18)
plt.legend(fontsize=18)
fig.savefig('cict01032018_25_.pdf')
plt.show()

# %% [markdown]
# ### Ablation on CICIDS

# %%
dataset_path = "../data/processed/cic/new/feature_group_5__.npz"
dataset = IDS2018Dataset(path=dataset_path, pct=.25)
train_set, test_set, val_set = dataset.split_train_test(test_pct= .5,
                         label= 0,
                         holdout=0.4,
                         contamination_rate=0.05,
                         validation_ratio= 0.0,
                         debug=True)
# Out:
# Dataset size
# Positive class :23100
# Negative class :58944
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [254], in <cell line: 3>()
#       1 dataset_path = "../data/processed/cic/new/feature_group_5__.npz"
#       2 dataset = IDS2018Dataset(path=dataset_path, pct=.25)
# ----> 3 train_set, test_set, val_set = dataset.split_train_test(test_pct= .5,
#       4                          label= 0,
#       5                          holdout=0.4,
#       6                          contamination_rate=0.25,
#       7                          validation_ratio= 0.0,
#       8                          debug=True)
#
# File ~\Documents\MobaXterm\home\projects\anomaly_detection_NRCAN\src\datamanager\dataset.py:255, in split_train_test(self, test_pct, label, holdout, contamination_rate, validation_ratio, seed, debug, corruption_label)
#     249     print(f"Dataset size\nPositive class :{len(abnormal_data_idx)}"
#     250           f"\nNegative class :{len(normal_data_idx)}\n")
#     252 if holdout > 0:
#     253     # Generate test set by holding out a percentage [holdout] of abnormal
#     254     # sample for a possible contamination
# --> 255     shuffled_abnorm_idx = torch.randperm(len(abnormal_data_idx)).long()
#     256     num_abnorm_test_sample = int(len(abnormal_data_idx) * (1 - holdout))
#     257     abnorm_test_idx = abnormal_data_idx[shuffled_abnorm_idx[:num_abnorm_test_sample]]
#
# AssertionError:

# %%
y =  train_set[:][1]
normal_idx = np.where(y == 0)
abnormal_idx = np.where(y == 1)

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(train_set[:][0])

# %%
labels = train_set[:][2].reshape(-1)

# %%
np.unique(labels[np.where(labels!="Benign")])
# Out:
# array(['Infilteration'], dtype=object)

# %% [markdown]
# ### Ablation on CICIDS

# %%
dataset_path = "../data/processed/cicnew/3_minified/feature_group_5.npz"
dataset = IDS2018Dataset(path=dataset_path, pct=.25)

# %%
CONTAMINATION_RATE = 0.0
train_set, test_set, val_set = dataset.split_train_test(test_pct= .5,
                         label= 0,
                         holdout=0.4,
                         contamination_rate=CONTAMINATION_RATE,
                         validation_ratio= 0.0,
                         debug=True)
# Out:
# Dataset size
# Positive class :686733
# Negative class :3347558
#
# Training set
# Contamination rate: 0.0
#
# 4034291 3759597

# %%
y =  train_set[:][1]
normal_idx = np.where(y == 0)
abnormal_idx = np.where(y == 1)

# %%
abnormal_idx
# Out:
# (array([], dtype=int64),)

# %%
np.unique(train_set[:][3])
# Out:
# array(['Benign'], dtype=object)

# %% [markdown]
# ### Attack distribution

# %%
mappin_att = ['Brute Force','DDoS', 'DoS']
def attack_map(x: str):
    newname = [el for el in mappin_att if x.lower().startswith(el.lower())]
    return newname[0] if len(newname)>0 else x

# %%
labels = dataset[:][3]

# %%
attack_idx = np.where(labels!="Benign")
attack_labels = labels[attack_idx]
attack_labels = np.array(list(map(attack_map, attack_labels)))
labels[attack_idx] = attack_labels

# %%
# Attack count in the 
attack, attack_count = np.unique(labels, return_counts=True)
dict(zip(attack, attack_count))
# Out:
# {'Benign': 3347558,
#  'Bot': 71373,
#  'Brute Force': 229,
#  'DDoS': 316196,
#  'DoS': 163545,
#  'FTP-BruteForce': 48344,
#  'Infilteration': 40287,
#  'SQL Injection': 24,
#  'SSH-Bruteforce': 46735}

# %%
# fig = plt.figure()
def plot_hist(attack, attack_count, name='hist'):
    fig, ax = plt.subplots(figsize=(10, 8))
    yax_v = np.arange(len(attack))
    ax.barh(yax_v, attack_count)
    ax.set_yticks(yax_v, labels=attack)
    ax.invert_yaxis()
    # ax.xaxis.set_major_formatter(ticker.EngFormatter())
    plt.title("")
    plt.ylabel('', fontsize=18)
    plt.xlabel('', fontsize=18)
    plt.tick_params(labelsize=18)
    # plt.legend(fontsize=18)
    fig.savefig(f'{name}.pdf')
    plt.show()

# %%
plot_hist(attack, attack_count/np.sum(attack_count), name='cicall')

# %%
# Attack count in the 
attack, attack_count = np.unique(attack_labels, return_counts=True)
dict(zip(attack, attack_count))

plot_hist(attack, attack_count, name='cicattack')

# %%
dict(zip(attack, attack_count/np.sum(attack_count)))
# Out:
# {'Bot': 0.10393122217805173,
#  'Brute Force': 0.0003334629324642911,
#  'DDoS': 0.4604351327226156,
#  'DoS': 0.2381493244099235,
#  'FTP-BruteForce': 0.07039708300023444,
#  'Infilteration': 0.05866472122353229,
#  'SQL Injection': 3.494808025826631e-05,
#  'SSH-Bruteforce': 0.06805410545291984}

# %% [markdown]
# ### Attack distribution in different datasets

# %% [markdown]
# ### Training set

# %%
# Training set

tr_lbl = labels[train_set[:][2]]
tr_lbl = tr_lbl[tr_lbl != "Benign"]

# %%
tr_lbl_u, tr_lbl_count_u = np.unique(tr_lbl, return_counts=True)
dict(zip(tr_lbl_u, tr_lbl_count_u))
# Out:
# {}

# %%
dict(zip(tr_lbl_u, tr_lbl_count_u/np.sum(tr_lbl_count_u)))
# Out:
# {'Bot': 0.10299342740058802,
#  'Brute Force': 0.00027243935386466573,
#  'DDoS': 0.4613533424903227,
#  'DoS': 0.23816875347643968,
#  'FTP-BruteForce': 0.07064125412915896,
#  'Infilteration': 0.059119339788632465,
#  'SQL Injection': 1.1351639744361073e-05,
#  'SSH-Bruteforce': 0.06744009172124914}

# %%
plot_hist(tr_lbl_u, tr_lbl_count_, name='cicattack_tr')

# %% [markdown]
# #### Training DAE

# %%
def resolve_model(CONTAMINATION_RATE, corruption_label):
    BATCH_SIZE = 4096
    learning_rate = 1e-4
    train_set, test_set, val_set = dataset.split_train_test(test_pct= .5,
                             label= 0,
                             holdout=0.4,
                             contamination_rate=CONTAMINATION_RATE,
                             validation_ratio= 0.0,
                             corruption_label=corruption_label,
                             debug=True)

    
    train_ldr = DataLoader(dataset=train_set, batch_size=BATCH_SIZE, num_workers=0)
    test_ldr  = DataLoader(dataset=test_set, batch_size=BATCH_SIZE, num_workers=0)
    
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = AE(
                dataset_name=dataset.name,
                in_features=dataset.in_features,
                n_instances=dataset.n_instances,
                device=device,
                ae_latent_dim=2
            )
    trainer = AutoEncoderTrainer(
                model=model,
                lr=learning_rate,
                n_epochs=100,
                batch_size=BATCH_SIZE,
                device=device
            )
    return train_ldr, test_ldr, model, trainer, train_set, test_set

# %%
trainer.train(train_ldr)
# Out:
#   1%|▌                                                           | 4/409 [00:00<00:13, 30.83it/s, epoch=1, loss=14.829]
# Started training
# 100%|████████████████████████████████████████████████████████| 409/409 [00:13<00:00, 30.38it/s, epoch=1, loss=1021.144]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:13<00:00, 29.36it/s, epoch=2, loss=392.316]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:15<00:00, 27.09it/s, epoch=3, loss=195.475]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:15<00:00, 27.12it/s, epoch=4, loss=108.829]
# 100%|██████████████████████████████████████████████████████████| 409/409 [00:15<00:00, 25.84it/s, epoch=5, loss=72.327]
# 100%|██████████████████████████████████████████████████████████| 409/409 [00:14<00:00, 28.51it/s, epoch=6, loss=52.490]
# 100%|██████████████████████████████████████████████████████████| 409/409 [00:12<00:00, 31.86it/s, epoch=7, loss=42.434]
# 100%|██████████████████████████████████████████████████████████| 409/409 [00:12<00:00, 31.65it/s, epoch=8, loss=34.770]
# 100%|██████████████████████████████████████████████████████████| 409/409 [00:13<00:00, 30.51it/s, epoch=9, loss=29.718]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:12<00:00, 32.16it/s, epoch=10, loss=25.969]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:12<00:00, 32.32it/s, epoch=11, loss=23.092]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:12<00:00, 32.06it/s, epoch=12, loss=20.917]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:13<00:00, 29.67it/s, epoch=13, loss=19.195]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:14<00:00, 28.05it/s, epoch=14, loss=17.752]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:15<00:00, 27.11it/s, epoch=15, loss=16.500]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:14<00:00, 27.35it/s, epoch=16, loss=15.415]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:14<00:00, 27.42it/s, epoch=17, loss=14.450]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:15<00:00, 26.47it/s, epoch=18, loss=13.596]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:16<00:00, 25.04it/s, epoch=19, loss=12.833]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:15<00:00, 26.50it/s, epoch=20, loss=12.151]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:15<00:00, 26.96it/s, epoch=21, loss=11.538]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:15<00:00, 27.01it/s, epoch=22, loss=10.982]
# 100%|█████████████████████████████████████████████████████████| 409/409 [00:14<00:00, 28.99it/s, epoch=23, loss=10.475]
            scores.extend(score.cpu().tolist())
            idxs.extend(idx.cpu().tolist())
            lbls.extend(list(lbl))
    trainer.model.train()
    return np.array(scores), np.array(y_true), np.array(idxs), np.array(lbls)

# %%
def estimate_threshold(trainer, test_ldr):
    scores, y_true, idxs, lbls = test(trainer, test_ldr)
    loc_perm = np.random.permutation(np.arange(len(scores)))
    n_sample_v = int(.2 * len(scores))

    #  Randomly draw 20percent of data to find the threshold
    scores_test, y_true_test, lbls_test =  np.array(scores[loc_perm[n_sample_v:]]), np.array(y_true[loc_perm[n_sample_v:]]),\
    np.array(labels[idxs[loc_perm[n_sample_v:]]])
    scores_val, y_true_val =  np.array(scores[loc_perm[:n_sample_v]]), np.array(y_true[loc_perm[:n_sample_v]])

    # Estimate the threshold
    res = _estimate_optimal_threshold(scores_val, y_true_val, 1, 100)
    return scores_test, y_true_test, lbls_test, res

# %%
def get_metrics(scores_test, y_true_test, lbls_test, res):
    # Compute different metrics
    metrics = compute_metrics(scores_test, y_true_test, res['Thresh_star'], 1)
    f_res = {
            "Precision": metrics[1],
            "Recall": metrics[2],
            "F1-Score": metrics[3],
            "AUPR": metrics[5],
            "AUROC": metrics[4],
            # "Thresh_star": threshold,
            # "Quantile_star": qis
        }
    print(f"final metrics{f_res}")

    # Prediction 
    y_pred_test = trainer.predict(scores_test, res['Thresh_star'])

    # Stat of detection rate
    correct_pred_idx = np.where(y_pred_test == y_true_test)
    correct_pred_lbls = lbls_test[correct_pred_idx]

    # 
    test_lbl_u, test_lbl_count_u = np.unique(lbls_test, return_counts=True)
    test_lbl_u_dict = dict(zip(test_lbl_u, test_lbl_count_u))
    print(f'\nTest set sample per class count:\n{test_lbl_u_dict}')

    #
    corr_lbl_u, corr_lbl_count_u = np.unique(correct_pred_lbls, return_counts=True)
    corr_lbl_u_dict = dict(zip(corr_lbl_u, corr_lbl_count_u))
    print(f'\nCorrect prediction count:\n{corr_lbl_u_dict}')

    #
    pred_stat_by_class = {k : 100 * corr_lbl_u_dict.get(k, 0) / test_lbl_u_dict[k] for k in test_lbl_u }
    print(f'\nDetection ratio per class:\n{pred_stat_by_class}')
    
    return pred_stat_by_class, f_res
    # plot_hist(pred_stat_by_class.keys(), np.array(list(pred_stat_by_class.values())), name=f'cicattack_tr_detection{CONTAMINATION_RATE}')

# %%
pred_stat_by_class
# Out:
# {'Benign': 94.6215137954242,
#  'Bot': 98.42860462414313,
#  'Brute Force': 34.78260869565217,
#  'DDoS': 20.43149548220542,
#  'DoS': 97.5749148477465,
#  'FTP-BruteForce': 100.0,
#  'Infilteration': 14.332264404675701,
#  'SQL Injection': 0.0,
#  'SSH-Bruteforce': 99.99556717939625}

# %%
pred_stat_by_class_w_i
# Out:
# {'Benign': 86.62975339294715,
#  'Bot': 50.07250159503509,
#  'Brute Force': 45.91836734693877,
#  'DDoS': 21.101153212520593,
#  'DoS': 100.0,
#  'FTP-BruteForce': 100.0,
#  'Infilteration': 20.417101147028156,
#  'SQL Injection': 18.181818181818183,
#  'SSH-Bruteforce': 100.0}

# %%
att_count = dict(normal=np.array(list(pred_stat_by_class.values())), contaminated=np.array(list(pred_stat_by_class_w_i.values())))
att_count
# Out:
# {'normal': array([ 94.6215138 ,  98.42860462,  34.7826087 ,  20.43149548,
#          97.57491485, 100.        ,  14.3322644 ,   0.        ,
#          99.99556718]),
#  'contaminated': array([ 86.62975339,  50.0725016 ,  45.91836735,  21.10115321,
#         100.        , 100.        ,  20.41710115,  18.18181818,
#         100.        ])}

# %%
def plot_multibar(attack, attack_count, name='hist'):
    fig, ax = plt.subplots(figsize=(12, 8))
    yax_v = np.arange(len(attack))
    width = 0.4
    i = 0
    
    #TODO fix to generalize
    for k in attack_count.keys():
        if i == 0:
            ax.barh(yax_v - width/2, attack_count[k], width,label=k)
        else:
            ax.barh(yax_v + width/2, attack_count[k], width,label=k)
        i +=1
        
        
    ax.set_yticks(yax_v, labels=attack)
    ax.invert_yaxis()
    # ax.xaxis.set_major_formatter(ticker.EngFormatter())
    plt.title("")
    plt.ylabel('', fontsize=18)
    plt.xlabel('', fontsize=18)
    plt.tick_params(labelsize=18)
    plt.legend(fontsize=18)
    fig.savefig(f'{name}.pdf')
    fig.tight_layout()
    plt.show()

# %%
plot_multibar(attack, att_count, name='cicmultibar')

# %% [markdown]
# ## Training with different type of contamination

# %% [markdown]
# #### Corruption with DDOS

# %%
train_ldr_0, test_ldr_0, model_0, trainer_0, train_set_0, test_set_0 =  resolve_model(0.05, 'DDOS')
# Out:
# Dataset size
# Positive class :686733
# Negative class :3347558
#
# Training set
# Contamination rate: 0.04999965945312713
#
# 4034291 3847690

# %%
# np.unique(train_set_0[:][3])

# %%
trainer_0.train(train_ldr_0)
# Out:
#   1%|▌                                                           | 4/431 [00:00<00:16, 25.16it/s, epoch=1, loss=17.042]
# Started training
# 100%|████████████████████████████████████████████████████████| 431/431 [00:16<00:00, 25.49it/s, epoch=1, loss=1000.846]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:15<00:00, 27.02it/s, epoch=2, loss=329.964]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.87it/s, epoch=3, loss=188.517]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:13<00:00, 30.98it/s, epoch=4, loss=133.425]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.58it/s, epoch=5, loss=91.621]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.28it/s, epoch=6, loss=60.162]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.66it/s, epoch=7, loss=47.320]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 28.96it/s, epoch=8, loss=39.132]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.88it/s, epoch=9, loss=32.698]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.26it/s, epoch=10, loss=28.131]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.46it/s, epoch=11, loss=25.284]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.73it/s, epoch=12, loss=23.044]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.28it/s, epoch=13, loss=21.119]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.36it/s, epoch=14, loss=19.309]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:15<00:00, 28.53it/s, epoch=15, loss=17.775]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.89it/s, epoch=16, loss=16.557]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.41it/s, epoch=17, loss=15.507]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00,
████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.92it/s, epoch=65, loss=3.826]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.89it/s, epoch=66, loss=3.766]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.09it/s, epoch=67, loss=3.708]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.89it/s, epoch=68, loss=3.652]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.52it/s, epoch=69, loss=3.598]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:15<00:00, 28.44it/s, epoch=70, loss=3.546]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.90it/s, epoch=71, loss=3.495]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.31it/s, epoch=72, loss=3.445]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.16it/s, epoch=73, loss=3.397]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.03it/s, epoch=74, loss=3.350]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:13<00:00, 30.80it/s, epoch=75, loss=3.305]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:15<00:00, 28.26it/s, epoch=76, loss=3.261]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.46it/s, epoch=77, loss=3.217]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.40it/s, epoch=78, loss=3.176]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.01it/s, epoch=79, loss=3.135]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.31it/s, epoch=80, loss=3.095]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.80it/s, epoch=81, loss=3.056]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 28.86it/s, epoch=82, loss=3.018]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.65it/s, epoch=83, loss=2.981]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.95it/s, epoch=84, loss=2.945]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.42it/s, epoch=85, loss=2.910]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.57it/s, epoch=86, loss=2.875]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.19it/s, epoch=87, loss=2.841]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.98it/s, epoch=88, loss=2.809]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.01it/s, epoch=89, loss=2.776]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.91it/s, epoch=90, loss=2.745]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.81it/s, epoch=91, loss=2.714]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.01it/s, epoch=92, loss=2.684]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.48it/s, epoch=93, loss=2.655]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.25it/s, epoch=94, loss=2.626]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 28.74it/s, epoch=95, loss=2.598]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.59it/s, epoch=96, loss=2.571]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.54it/s, epoch=97, loss=2.544]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 30.37it/s, epoch=98, loss=2.517]
# 100%|██████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.87it/s, epoch=99, loss=2.492]
# 100%|█████████████████████████████████████████████████████████| 431/431 [00:14<00:00, 29.95it/s, epoch=100, loss=2.466]

# %%
scores_test0, y_true_test0, lbls_test0, res0 = estimate_threshold(trainer_0, test_ldr_0)
# Out:
# Ratio of normal data:80.22571512813936

# %%
pred_stat0 = get_metrics(scores_test0, y_true_test0, lbls_test0, res0)
pred_stat0
# Out:
# final metrics{'Precision': 0.6312384847069553, 'Recall': 0.5208558389066236, 'F1-Score': 0.5707592577506071, 'AUPR': 0.4609476271084219, 'AUROC': 0.71347629601974}
#
# Test set sample per class count:
# {'Benign': 1339107, 'Bot': 34300, 'Brute Force': 106, 'DDoS': 152056, 'DoS': 78521, 'FTP-BruteForce': 23187, 'Infilteration': 19196, 'SQL Injection': 15, 'SSH-Bruteforce': 22167}
#
# Correct prediction count:
# {'Benign': 1238833, 'Bot': 33780, 'Brute Force': 43, 'DDoS': 10973, 'DoS': 78495, 'FTP-BruteForce': 23187, 'Infilteration': 3002, 'SQL Injection': 1, 'SSH-Bruteforce': 22166}
#
# Detection ratio per class:
# {'Benign': 92.51187545132689, 'Bot': 98.48396501457727, 'Brute Force': 40.56603773584906, 'DDoS': 7.2164202662177095, 'DoS': 99.96688783892208, 'FTP-BruteForce': 100.0, 'Infilteration': 15.638674723900813, 'SQL Injection': 6.666666666666667, 'SSH-Bruteforce': 99.99548878964227}
# {'Benign': 92.51187545132689,
#  'Bot': 98.48396501457727,
#  'Brute Force': 40.56603773584906,
#  'DDoS': 7.2164202662177095,
#  'DoS': 99.96688783892208,
#  'FTP-BruteForce': 100.0,
#  'Infilteration': 15.638674723900813,
#  'SQL Injection': 6.666666666666667,
#  'SSH-Bruteforce': 99.99548878964227}

# %% [markdown]
# #### Corruption with DOS

# %%
train_ldr_1, test_ldr_1, model_1, trainer_1, train_set_1, test_set_1 =  resolve_model(0.037, 'DOS')
np.unique(train_set_1[:][3])
# Out:
# Dataset size
# Positive class :686733
# Negative class :3347558
#
# Training set
# Contamination rate: 0.0369998527117154
#
# 4034291 3823906
# array(['Benign', 'DoS'], dtype=object)

# %%
trainer_1.train(train_ldr_1)
# Out:
#   1%|▋                                                           | 5/425 [00:00<00:13, 30.87it/s, epoch=1, loss=19.310]
# Started training
# 100%|████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 28.66it/s, epoch=1, loss=1022.899]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:13<00:00, 30.48it/s, epoch=2, loss=328.598]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.25it/s, epoch=3, loss=183.997]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.85it/s, epoch=4, loss=121.563]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.32it/s, epoch=5, loss=75.716]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.24it/s, epoch=6, loss=51.849]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.07it/s, epoch=7, loss=41.467]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 28.70it/s, epoch=8, loss=35.619]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.05it/s, epoch=9, loss=31.043]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.10it/s, epoch=10, loss=27.358]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.79it/s, epoch=11, loss=24.500]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:13<00:00, 30.48it/s, epoch=12, loss=22.235]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.23it/s, epoch=13, loss=20.373]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.12it/s, epoch=14, loss=18.802]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 28.38it/s, epoch=15, loss=17.454]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.24it/s, epoch=16, loss=16.281]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:13<00:00, 30.76it/s, epoch=17, loss=15.253]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.86it/s, epoch=18, loss=14.347]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.50it/s, epoch=19, loss=13.541]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.18it/s, epoch=20, loss=12.817]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 28.52it/s, epoch=21, loss=12.157]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.24it/s, epoch=22, loss=11.558]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:13<00:00, 30.44it/s, epoch=23, loss=11.012]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00,
████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.50it/s, epoch=68, loss=3.580]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.93it/s, epoch=69, loss=3.527]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 28.50it/s, epoch=70, loss=3.476]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.86it/s, epoch=71, loss=3.426]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.95it/s, epoch=72, loss=3.378]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.79it/s, epoch=73, loss=3.331]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.77it/s, epoch=74, loss=3.285]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.14it/s, epoch=75, loss=3.241]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.90it/s, epoch=76, loss=3.197]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:15<00:00, 28.17it/s, epoch=77, loss=3.155]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.91it/s, epoch=78, loss=3.114]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.85it/s, epoch=79, loss=3.074]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.98it/s, epoch=80, loss=3.035]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.02it/s, epoch=81, loss=2.997]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.85it/s, epoch=82, loss=2.960]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 28.34it/s, epoch=83, loss=2.923]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.51it/s, epoch=84, loss=2.888]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.99it/s, epoch=85, loss=2.854]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.71it/s, epoch=86, loss=2.820]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.95it/s, epoch=87, loss=2.787]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.02it/s, epoch=88, loss=2.755]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.08it/s, epoch=89, loss=2.723]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 28.59it/s, epoch=90, loss=2.693]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.27it/s, epoch=91, loss=2.663]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.00it/s, epoch=92, loss=2.633]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.28it/s, epoch=93, loss=2.605]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.80it/s, epoch=94, loss=2.577]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.23it/s, epoch=95, loss=2.549]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.13it/s, epoch=96, loss=2.522]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 28.35it/s, epoch=97, loss=2.496]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 29.81it/s, epoch=98, loss=2.470]
# 100%|██████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.05it/s, epoch=99, loss=2.445]
# 100%|█████████████████████████████████████████████████████████| 425/425 [00:14<00:00, 30.34it/s, epoch=100, loss=2.420]

# %%
scores_test1, y_true_test1, lbls_test1, res1 = estimate_threshold(trainer_1, test_ldr_1)
pred_stat1 = get_metrics(scores_test1, y_true_test1, lbls_test1, res1)
pred_stat1
# Out:
# Ratio of normal data:80.23218741834727
# final metrics{'Precision': 0.44994077404694566, 'Recall': 0.5647485397860882, 'F1-Score': 0.5008496525371849, 'AUPR': 0.4976027943244731, 'AUROC': 0.8518458659833932}
#
# Test set sample per class count:
# {'Benign': 1339080, 'Bot': 34327, 'Brute Force': 106, 'DDoS': 151609, 'DoS': 78540, 'FTP-BruteForce': 23070, 'Infilteration': 19548, 'SQL Injection': 11, 'SSH-Bruteforce': 22364}
#
# Correct prediction count:
# {'Benign': 1111537, 'Bot': 33784, 'Brute Force': 48, 'DDoS': 84767, 'DoS': 25433, 'FTP-BruteForce': 23070, 'Infilteration': 4795, 'SQL Injection': 3, 'SSH-Bruteforce': 14227}
#
# Detection ratio per class:
# {'Benign': 83.0075126206052, 'Bot': 98.41815480525534, 'Brute Force': 45.283018867924525, 'DDoS': 55.91158836216847, 'DoS': 32.38222561751974, 'FTP-BruteForce': 100.0, 'Infilteration': 24.52936361776141, 'SQL Injection': 27.272727272727273, 'SSH-Bruteforce': 63.615632266142015}
# {'Benign': 83.0075126206052,
#  'Bot': 98.41815480525534,
#  'Brute Force': 45.283018867924525,
#  'DDoS': 55.91158836216847,
#  'DoS': 32.38222561751974,
#  'FTP-BruteForce': 100.0,
#  'Infilteration': 24.52936361776141,
#  'SQL Injection': 27.272727272727273,
#  'SSH-Bruteforce': 63.615632266142015}

# %% [markdown]
# #### Corruption with Bot

# %%
train_ldr_2, test_ldr_2, model_2, trainer_2, train_set_2, test_set_2 =  resolve_model(0.016, 'bot')
np.unique(train_set_2[:][3])
# Out:
# Dataset size
# Positive class :686733
# Negative class :3347558
#
# Training set
# Contamination rate: 0.015999468546038374
#
# 4034291 3786812
# array(['Benign', 'Bot'], dtype=object)

# %%
trainer_2.train(train_ldr_2)
# Out:
#   1%|▋                                                           | 5/416 [00:00<00:12, 33.32it/s, epoch=1, loss=20.394]
# Started training
# 100%|████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 29.79it/s, epoch=1, loss=1078.528]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.46it/s, epoch=2, loss=341.074]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.17it/s, epoch=3, loss=149.369]
# 100%|██████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.07it/s, epoch=4, loss=87.631]
# 100%|██████████████████████████████████████████████████████████| 416/416 [00:14<00:00, 28.97it/s, epoch=5, loss=63.690]
# 100%|██████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.56it/s, epoch=6, loss=49.205]
# 100%|██████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 29.86it/s, epoch=7, loss=40.641]
# 100%|██████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.24it/s, epoch=8, loss=34.861]
# 100%|██████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.11it/s, epoch=9, loss=30.468]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.12it/s, epoch=10, loss=26.993]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 29.78it/s, epoch=11, loss=24.262]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 29.97it/s, epoch=12, loss=22.091]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:14<00:00, 28.78it/s, epoch=13, loss=20.286]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.06it/s, epoch=14, loss=18.739]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.33it/s, epoch=15, loss=17.391]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.23it/s, epoch=16, loss=16.200]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.50it/s, epoch=17, loss=15.146]
# 100%|██████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.21it/s, epoch=98, loss=2.411]
# 100%|██████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 29.99it/s, epoch=99, loss=2.387]
# 100%|█████████████████████████████████████████████████████████| 416/416 [00:13<00:00, 30.08it/s, epoch=100, loss=2.362]

# %%
scores_test2, y_true_test2, lbls_test2, res2 = estimate_threshold(trainer_2, test_ldr_2)
pred_stat2 = get_metrics(scores_test2, y_true_test2, lbls_test2, res2)
pred_stat2
# Out:
# Ratio of normal data:80.2952323192613
# final metrics{'Precision': 0.6046205025218071, 'Recall': 0.47829540562336664, 'F1-Score': 0.5340898703708092, 'AUPR': 0.45632953802286264, 'AUROC': 0.760512770658212}
#
# Test set sample per class count:
# {'Benign': 1338817, 'Bot': 34193, 'Brute Force': 114, 'DDoS': 151705, 'DoS': 78714, 'FTP-BruteForce': 23152, 'Infilteration': 19384, 'SQL Injection': 16, 'SSH-Bruteforce': 22560}
#
# Correct prediction count:
# {'Benign': 1235653, 'Bot': 26, 'Brute Force': 49, 'DDoS': 29705, 'DoS': 78713, 'FTP-BruteForce': 23152, 'Infilteration': 3554, 'SQL Injection': 1, 'SSH-Bruteforce': 22560}
#
# Detection ratio per class:
# {'Benign': 92.29439124241775, 'Bot': 0.07603895534173662, 'Brute Force': 42.98245614035088, 'DDoS': 19.58076530107775, 'DoS': 99.9987295779658, 'FTP-BruteForce': 100.0, 'Infilteration': 18.334709038382172, 'SQL Injection': 6.25, 'SSH-Bruteforce': 100.0}
# {'Benign': 92.29439124241775,
#  'Bot': 0.07603895534173662,
#  'Brute Force': 42.98245614035088,
#  'DDoS': 19.58076530107775,
#  'DoS': 99.9987295779658,
#  'FTP-BruteForce': 100.0,
#  'Infilteration': 18.334709038382172,
#  'SQL Injection': 6.25,
#  'SSH-Bruteforce': 100.0}

# %% [markdown]
# ### Viz of classes accuracy

# %%
attack_to_viz = pred_stat_by_class.keys()
attack_to_viz
# Out:
# dict_keys(['Benign', 'Bot', 'Brute Force', 'DDoS', 'DoS', 'FTP-BruteForce', 'Infilteration', 'SQL Injection', 'SSH-Bruteforce'])

# %%
name = 'cic2018_selective_inj'
fig, ax = plt.subplots(figsize=(10, 6))
yax_v = np.arange(len(attack_to_viz))
width = 0.16

ax.barh(yax_v - 3*width/2, list(pred_stat_by_class.values()), width,label='Normal')
ax.barh(yax_v - width/2, list(pred_stat0.values()), width,label='+DDoS')
ax.barh(yax_v + width/2 , list(pred_stat1.values()), width,label='+DoS')
ax.barh(yax_v + 3 * width/2 , list(pred_stat2.values()), width,label='+Bot')


ax.set_yticks(yax_v, labels=attack_to_viz)
ax.invert_yaxis()
# ax.xaxis.set_major_formatter(ticker.EngFormatter())
plt.title("")
plt.ylabel('', fontsize=18)
plt.xlabel('', fontsize=18)
plt.tick_params(labelsize=18)
plt.legend(fontsize=18, loc=(1.04, 0))
fig.savefig(f'{name}.pdf')
fig.tight_layout()
plt.show()
